# %% [markdown]
# # AdaBoost (Adaptive Boosting)
# - It is a sequential ensemble machine learning algorithm that combines multiple "weak learners" to form a single, highly accurate "strong learner".
# - It achieves this by iteratively training models—typically one-level decision trees called decision stumps—and dynamically increasing the weights of misclassified data points so that subsequent models focus heavily on correcting previous mistakes.

# %%
import numpy as np
import pandas as pd
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.DataFrame()

# %%
df['X1'] = [1,2,3,4,5,6,6,7,9,9]
df['X2'] = [5,3,6,8,1,9,5,8,9,2]
df['label'] = [1,1,0,1,0,1,0,1,0,0]

# %%
df
# Out:
#    X1  X2  label
# 0   1   5      1
# 1   2   3      1
# 2   3   6      0
# 3   4   8      1
# 4   5   1      0
# 5   6   9      1
# 6   6   5      0
# 7   7   8      1
# 8   9   9      0
# 9   9   2      0

# %%
import seaborn as sns
sns.scatterplot(x=df['X1'], y=df['X2'], hue=df['label'])
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
df['weights'] = 1/df.shape[0]

# %%
df
# Out:
#    X1  X2  label  weights
# 0   1   5      1      0.1
# 1   2   3      1      0.1
# 2   3   6      0      0.1
# 3   4   8      1      0.1
# 4   5   1      0      0.1
# 5   6   9      1      0.1
# 6   6   5      0      0.1
# 7   7   8      1      0.1
# 8   9   9      0      0.1
# 9   9   2      0      0.1

# %%
from sklearn.tree import DecisionTreeClassifier
dt1 = DecisionTreeClassifier(max_depth=1) # decision Stump

# %%
X = df.iloc[:,0:2].values
y = df.iloc[:,2].values

# %%
dt1.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
from sklearn.tree import plot_tree
plot_tree(dt1)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 2.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_decision_regions(X, y, clf=dt1, legend=2)
# Out:
# <Axes: >

# %%
df['y_pred'] = dt1.predict(X)

# %%
df
# Out:
#    X1  X2  label  weights  y_pred
# 0   1   5      1      0.1       1
# 1   2   3      1      0.1       1
# 2   3   6      0      0.1       0
# 3   4   8      1      0.1       0
# 4   5   1      0      0.1       0
# 5   6   9      1      0.1       0
# 6   6   5      0      0.1       0
# 7   7   8      1      0.1       0
# 8   9   9      0      0.1       0
# 9   9   2      0      0.1       0

# %%
def calculate_model_weight(error):
  return 0.5*np.log((1-error)/(error))

# %% [markdown]
# ### Calculate model weight

# %%
alpha1 = calculate_model_weight(0.3)
alpha1
# Out:
# np.float64(0.42364893019360184)

# %% [markdown]
# ### Update weights or Upsampling the incorrectly classified points

# %%
def update_row_weights(row, alpha=0.423):
  if row['label'] == row['y_pred']:  # if points are correctly classified, decreased the weights
    return row['weights']*np.exp(-alpha)
  else:  # if points are incorrectly classified, then Increased the weigths
    return row['weights']*np.exp(alpha)

# %%
df['updated_weights'] = df.apply(update_row_weights, axis=1)

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights
# 0   1   5      1      0.1       1         0.065508
# 1   2   3      1      0.1       1         0.065508
# 2   3   6      0      0.1       0         0.065508
# 3   4   8      1      0.1       0         0.152653
# 4   5   1      0      0.1       0         0.065508
# 5   6   9      1      0.1       0         0.152653
# 6   6   5      0      0.1       0         0.065508
# 7   7   8      1      0.1       0         0.152653
# 8   9   9      0      0.1       0         0.065508
# 9   9   2      0      0.1       0         0.065508

# %%
df['updated_weights'].sum()
# Out:
# np.float64(0.9165153319682015)

# %%
df['normalized_weights'] = df['updated_weights'] / df['updated_weights'].sum()

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  normalized_weights
# 0   1   5      1      0.1       1         0.065508            0.071475
# 1   2   3      1      0.1       1         0.065508            0.071475
# 2   3   6      0      0.1       0         0.065508            0.071475
# 3   4   8      1      0.1       0         0.152653            0.166559
# 4   5   1      0      0.1       0         0.065508            0.071475
# 5   6   9      1      0.1       0         0.152653            0.166559
# 6   6   5      0      0.1       0         0.065508            0.071475
# 7   7   8      1      0.1       0         0.152653            0.166559
# 8   9   9      0      0.1       0         0.065508            0.071475
# 9   9   2      0      0.1       0         0.065508            0.071475

# %%
df['normalized_weights'].sum()
# Out:
# np.float64(1.0)

# %%
df['cumsum_upper'] = np.cumsum(df['normalized_weights'])

# %%
df['cumsum_lower'] = df['cumsum_upper'] - df['normalized_weights']

# %%
df[['X1','X2','label','weights','y_pred','updated_weights','cumsum_lower','cumsum_upper']]
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  cumsum_lower  cumsum_upper
# 0   1   5      1      0.1       1         0.065508      0.000000      0.071475
# 1   2   3      1      0.1       1         0.065508      0.071475      0.142950
# 2   3   6      0      0.1       0         0.065508      0.142950      0.214425
# 3   4   8      1      0.1       0         0.152653      0.214425      0.380983
# 4   5   1      0      0.1       0         0.065508      0.380983      0.452458
# 5   6   9      1      0.1       0         0.152653      0.452458      0.619017
# 6   6   5      0      0.1       0         0.065508      0.619017      0.690492
# 7   7   8      1      0.1       0         0.152653      0.690492      0.857050
# 8   9   9      0      0.1       0         0.065508      0.857050      0.928525
# 9   9   2      0      0.1       0         0.065508      0.928525      1.000000

# %% [markdown]
# ### Take random values and find the range and return the indices for those random values

# %%
def create_new_dataset(df):
  indices = []

  for i in range(df.shape[0]):
    a = np.random.random()
    for index,row in df.iterrows():
      if row['cumsum_upper']>a and a>row['cumsum_lower']:
        indices.append(index)
  return indices

# %%
index_values = create_new_dataset(df)
index_values
# Out:
# [1, 3, 2, 0, 8, 7, 5, 3, 3, 5]

# %%
second_df = df.iloc[index_values,[0,1,2,3]]
second_df
# Out:
#    X1  X2  label  weights
# 1   2   3      1      0.1
# 3   4   8      1      0.1
# 2   3   6      0      0.1
# 0   1   5      1      0.1
# 8   9   9      0      0.1
# 7   7   8      1      0.1
# 5   6   9      1      0.1
# 3   4   8      1      0.1
# 3   4   8      1      0.1
# 5   6   9      1      0.1

# %%
dt2 = DecisionTreeClassifier(max_depth=1)

# %%
X = second_df.iloc[:,0:2].values
y = second_df.iloc[:,2].values

# %%
dt2.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plot_tree(dt2)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 8.0\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.25, 0.25, 'gini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_decision_regions(X, y, clf=dt2, legend=2)
# Out:
# <Axes: >

# %%
second_df['y_pred'] = dt2.predict(X)
second_df
# Out:
#    X1  X2  label  weights  y_pred
# 1   2   3      1      0.1       1
# 3   4   8      1      0.1       1
# 2   3   6      0      0.1       1
# 0   1   5      1      0.1       1
# 8   9   9      0      0.1       0
# 7   7   8      1      0.1       1
# 5   6   9      1      0.1       1
# 3   4   8      1      0.1       1
# 3   4   8      1      0.1       1
# 5   6   9      1      0.1       1

# %%
alpha2 = calculate_model_weight(0.1)
alpha2
# Out:
# np.float64(1.0986122886681098)

# %%
def update_row_weights(row, alpha=1.098):
  if row['label'] == row['y_pred']:  # if points are correctly classified, decreased the weights
    return row['weights']*np.exp(-alpha)
  else:  # if points are incorrectly classified, then Increased the weigths
    return row['weights']*np.exp(alpha)

# %%
second_df['updated_weights'] = second_df.apply(update_row_weights, axis=1)

# %%
second_df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  normalized_weights  \
# 1   2   3      1      0.1       1         0.033354             0.07693
# 3   4   8      1      0.1       1         0.033354             0.07693
# 2   3   6      0      0.1       1         0.299816             0.30763
# 0   1   5      1      0.1       1         0.033354             0.07693
# 8   9   9      0      0.1       0         0.033354             0.07693
# 7   7   8      1      0.1       1         0.033354             0.07693
# 5   6   9      1      0.1       1         0.033354             0.07693
# 3   4   8      1      0.1       1         0.033354             0.07693
# 3   4   8      1      0.1       1         0.033354             0.07693
# 5   6   9      1      0.1       1         0.033354             0.07693
#
#    cumsum_upper  cumsum_lower
# 1       0.07693       0.00000
# 3       0.15386       0.07693
# 2       0.46149       0.15386
# 0       0.53842       0.46149
# 8       0.61535       0.53842
# ...

# %%
second_df['updated_weights'].sum()
# Out:
# np.float64(0.6000001124692275)

# %%
second_df['normalized_weights'] = second_df['updated_weights'] / second_df['updated_weights'].sum()
second_df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  normalized_weights  \
# 1   2   3      1      0.1       1         0.033354            0.055590
# 3   4   8      1      0.1       1         0.033354            0.055590
# 2   3   6      0      0.1       1         0.299816            0.499694
# 0   1   5      1      0.1       1         0.033354            0.055590
# 8   9   9      0      0.1       0         0.033354            0.055590
# 7   7   8      1      0.1       1         0.033354            0.055590
# 5   6   9      1      0.1       1         0.033354            0.055590
# 3   4   8      1      0.1       1         0.033354            0.055590
# 3   4   8      1      0.1       1         0.033354            0.055590
# 5   6   9      1      0.1       1         0.033354            0.055590
#
#    cumsum_upper  cumsum_lower
# 1       0.07693       0.00000
# 3       0.15386       0.07693
# 2       0.46149       0.15386
# 0       0.53842       0.46149
# 8       0.61535       0.53842
# ...

# %%
second_df['normalized_weights'].sum()
# Out:
# np.float64(1.0)

# %%
second_df['cumsum_upper'] = np.cumsum(second_df['normalized_weights'])

# %%
second_df['cumsum_lower'] = second_df['cumsum_upper'] - second_df['normalized_weights']

# %%
second_df[['X1','X2','label','weights','y_pred','updated_weights','cumsum_lower','cumsum_upper']]
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  cumsum_lower  cumsum_upper
# 1   2   3      1      0.1       1         0.033354      0.000000      0.055590
# 3   4   8      1      0.1       1         0.033354      0.055590      0.111179
# 2   3   6      0      0.1       1         0.299816      0.111179      0.610873
# 0   1   5      1      0.1       1         0.033354      0.610873      0.666463
# 8   9   9      0      0.1       0         0.033354      0.666463      0.722052
# 7   7   8      1      0.1       1         0.033354      0.722052      0.777642
# 5   6   9      1      0.1       1         0.033354      0.777642      0.833231
# 3   4   8      1      0.1       1         0.033354      0.833231      0.888821
# 3   4   8      1      0.1       1         0.033354      0.888821      0.944410
# 5   6   9      1      0.1       1         0.033354      0.944410      1.000000

# %%
index_values = create_new_dataset(second_df)
index_values
# Out:
# [7, 5, 2, 8, 2, 8, 3, 0, 2, 2]

# %%
third_df = second_df.iloc[index_values,[0,1,2,3]]
third_df
# Out:
#    X1  X2  label  weights
# 3   4   8      1      0.1
# 7   7   8      1      0.1
# 2   3   6      0      0.1
# 3   4   8      1      0.1
# 2   3   6      0      0.1
# 3   4   8      1      0.1
# 0   1   5      1      0.1
# 1   2   3      1      0.1
# 2   3   6      0      0.1
# 2   3   6      0      0.1

# %%
dt3 = DecisionTreeClassifier(max_depth=1)
X = third_df.iloc[:,0:2].values
y = third_df.iloc[:,2].values

dt3.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plot_tree(dt3)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 7.0\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.25, 0.25, 'gini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_decision_regions(X, y, clf=dt3, legend=2)
# Out:
# <Axes: >

# %%
third_df['y_pred'] = dt3.predict(X)
third_df
# Out:
#    X1  X2  label  weights  y_pred
# 3   4   8      1      0.1       1
# 7   7   8      1      0.1       1
# 2   3   6      0      0.1       0
# 3   4   8      1      0.1       1
# 2   3   6      0      0.1       0
# 3   4   8      1      0.1       1
# 0   1   5      1      0.1       0
# 1   2   3      1      0.1       0
# 2   3   6      0      0.1       0
# 2   3   6      0      0.1       0

# %%
alpha3 = calculate_model_weight(0.2)
alpha3
# Out:
# np.float64(0.6931471805599453)

# %%
print(alpha1,alpha2,alpha3)
# Out:
# 0.42364893019360184 1.0986122886681098 0.6931471805599453

# %% [markdown]
# # Prediction

# %%
# Prediction 1
query = np.array([1,5]).reshape(1,2)

# %%
dt1.predict(query)
# Out:
# array([1])

# %%
dt2.predict(query)
# Out:
# array([1])

# %%
dt3.predict(query)
# Out:
# array([0])

# %%
alpha1*1 + alpha2*1 + alpha3*(-1)
# Out:
# np.float64(0.8291140383017664)

# %%
np.sign(0.829)
# Out:
# np.float64(1.0)

# %%
# Prediction 2
query = np.array([9,9]).reshape(1,2)
print(dt1.predict(query))
print(dt2.predict(query))
print(dt3.predict(query))
# Out:
# [0]
# [0]
# [1]

# %%
alpha1*(-1) + alpha2*(-1) + alpha3*1
# Out:
# np.float64(-0.8291140383017664)

# %%
np.sign(-0.829)
# Out:
# np.float64(-1.0)
